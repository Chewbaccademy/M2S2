68247681615009, 69.96271444633088, 52.386312190797625, 43.37261733968375, 31.8032602749647, 45.44308009969601, 40.63964686970972, 52.153496666002944, 80.28998880325614, 58.57085755426052, 64.66499337732638, 37.83038947575537, 76.91074604877154, 43.99599411782833, 49.871732678154316, 53.9935813467134, 45.62948652675443, 31.745476596414004, 65.80923459320003, 55.78585693375369, 52.89091281654659, 58.05445779952504, 31.46455675247858, 100.0, 66.40305385085446, 66.61315706637656, 62.89419422533741, 55.90817633048063, 48.85672024114095, 16.02289946370001, 68.91079815198894, 48.18640663496652, 34.564941724692524, 36.345937154127, 24.178051942619547, 74.84863712429544, 17.08081301050585, 15.71049170713455, 42.501064426637306, 76.85357213082523, 74.71022480489395, 24.40451271507469, 23.540872275694685, 38.34779648334142, 48.40436985033521, 71.48261020472637, 78.88951630021808, 57.12106569977281, 49.58972682867596, 36.39689017533619, 26.1812036141705, 60.38998239240129, 47.54095828348623, 34.65740729230984, 74.8522395340805, 55.24389595481103, 43.90979537711563, 47.832498419419544, 38.66290330453565, 47.37092327819375, 25.76240431848453, 86.31556117900996, 59.59674561796689, 43.223979088022176, 41.27895625878255, 84.56345724199488, 18.198631032486936, 32.477426427112846, 56.930806045214275, 39.67977139816933]


X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=42)


#Linear regression
LR = LinearRegression().fit(X_train, y_train)
beta_1 = LR.coef_[0]
beta_0= LR.intercept_
X_display = np.linspace(min(X), max(X), num=500)
y_hat=[]
for x in X_display:
  y_hat.append(beta_1*x+beta_0)

#Display
plt.figure(figsize=(8, 8))
plt.scatter(X,Y,color="black",linewidth=0.87)
plt.plot(X_display,y_hat,color="purple")
plt.grid()
print("")
print("Beta_1 :",beta_1)
print("Beta_0 :",beta_0)
print("MSE : ",mean_squared_error(y_train, LR.predict(X_train)))
print("MSE Val : ",mean_squared_error(y_test, LR.predict(X_test)))
# Out:
# Beta_1 : 7.692451393507596
# Beta_0 : -43.949921514125045
# MSE :  49.36496686315999
# MSE Val :  70.53978529385557

# %% [markdown]
# ##LINEAR REGRESSION AND GRADIENT DESCENT

# %% [markdown]
# ### Mean Squarred Error (MSE)

# %%
def MSE(Y,Y_PRED):
  n = len(Y)
  sum = 0
  for k in range(0, len(Y)):
    sum += (Y[k]-Y_PRED[k])**2
  return sum/n

# %%
def partialDerivMSE_B1(X,errors):
  n= len(X)
  sum=0
  for i in range(0,len(X)):
    sum += -2*X[i][0] * errors[i]
  return sum/n

# %%
def partialDerivMSE_B0(errors):
  n=len(errors)
  sum = 0
  for i in range(0,len(errors)):
    sum += -2*errors[i]
  return sum/n

# %% [markdown]
# ### Gradient descent algorithm

# %%
def gradientDescent(X_train, X_test, y_train, y_test,epochs, alpha, beta_0,beta_1):
  
  betas0 = []
  betas1 = []
  MSE_train = []
  MSE_test = []

  for i in range(0,epochs):

    #Update Parameters
    errors_train = []
    for xti in range(0,len(X_train)):
      xi = X_train[xti][0]
      y_true = y_train[xti]
      y_pred = beta_0 + beta_1*xi
      error = y_true - y_pred
      errors_train.append(error)

    dB0 = partialDerivMSE_B0(errors_train)
    dB1 = partialDerivMSE_B1(X_train,errors_train)
    beta_0 -= alpha * dB0
    beta_1 -= alpha * dB1

    betas0.append(beta_0)
    betas1.append(beta_1)

    #Compute MSE on Train and Test
    pred=[]
    for xti in range(0,len(X_train)):
      xi = X_train[xti][0]
      y_pred = beta_0 + beta_1*xi
      pred.append(y_pred)
    
    lossTrain = MSE(y_train,pred)
    MSE_train.append(lossTrain)
    
    pred=[]
    for xti in range(0,len(X_test)):
      xi = X_test[xti][0]
      y_pred = beta_0 + beta_1*xi
      pred.append(y_pred)
    lossTest = MSE(y_test,pred)
    MSE_test.append(lossTest)

    if (i % 10000 == 0 or i==0 or i==epochs-1):
      print("Epoch "+str(i)+'/'+str(epochs)+" [==============================] "+"Loss: "+str(lossTrain) + " - Val_loss: "+str(lossTest)+" B0: ",str(beta_0)," B1: ",str(beta_1))
  
  return [MSE_train, MSE_test,betas0,betas1]

# %% [markdown]
# #### Learning phase

# %%
X = [[14.828200297790497], [12.717617670595427], [9.855722677610249], [13.285618331488184], [11.302064405386776], [14.11922134525173], [11.341455767968844], [13.856400108964912], [14.02919072210217], [15.008832244730058], [14.55475626093806], [16.345091416164923], [14.346166449988527], [11.95082028040622], [10.478765992767032], [12.729401941338756], [7.600824690300561], [13.78316858278339], [15.077498806239877], [5.950637239775639], [13.741785382528082], [12.7426938733701], [11.335675616074358], [14.788505294255184], [16.411609139535017], [16.164121922303885], [10.998403275202989], [12.41043490222512], [10.995733469426508], [9.509483439798323], [13.392781428779365], [13.43924504586418], [13.152638180449722], [11.175599490582403], [10.229939811196973], [12.992153089672808], [11.752481623835331], [13.404090062619085], [14.556362280257973], [11.770765625516809], [13.403489013771035], [10.807694999235103], [16.307574641020064], [11.20432445431588], [11.914616563191661], [11.519729617169606], [11.747240761026777], [10.887200613487188], [13.321877774149211], [13.02215898751189], [11.68084463350558], [12.512783641606154], [11.91465760762705], [16.19473511185379], [11.537294298959209], [13.359045723921152], [13.32815857850891], [12.035852558340457], [11.913532166562133], [7.531077713497768], [13.310209923486989], [11.93555924878366], [9.73416256498493], [10.744867265306619], [8.841212629669704], [14.921612476332221], [8.187705418717417], [7.716799388355505], [11.094281176897569], [14.418586822882272], [14.531314555985496], [8.969240746661772], [8.803695024081431], [9.447890875072444], [10.401956191943405], [16.448032038768478], [14.938862817805898], [13.104905678915086], [13.240300692661439], [11.139043188687044], [8.092399611593166], [12.777306474274665], [12.928420702974925], [9.179534877753923], [15.142805565547288], [12.2108792940294], [11.32631403516262], [12.466256938155166], [9.96792219916394], [12.15433924707204], [9.622516056444244], [15.890600071427057], [12.66882051171981], [11.245607391038659], [11.34840307260053], [17.130695461272346], [8.938129534466357], [10.700389479013229], [12.319974696049165], [11.726969060371964]]
# Epoch 80000/100000 [==============================] Loss: 49.36638246663869 - Val_loss: 70.53806771588826 B0:  -44.156057816957365  B1:  7.708817467284177
# Epoch 90000/100000 [==============================] Loss: 49.36534340779543 - Val_loss: 70.53856458195892 B0:  -44.05623586802524  B1:  7.700892160784069
# Epoch 99999/100000 [==============================] Loss: 49.36506703573106 - Val_loss: 70.53906659772849 B0:  -44.004756543721506  B1:  7.696804989296333

# %% [markdown]
# #### Display the optimisation

# %%
def displayHistory(epoch_min,epoch_max,history):
  

  epochs = np.arange(epoch_min,epoch_max,step=1)
  sMSE_Train = history[0][epoch_min:epoch_max]
  sMSE_Val = history[1][epoch_min:epoch_max]
  sBetas0 = history[2][epoch_min:epoch_max]
  sBetas1 = history[3][epoch_min:epoch_max]

  #MSE Test / Train
  fig, (ax1) = plt.subplots(1,figsize=(15, 4))
  ax1.plot(epochs,sMSE_Train,color="gray",label=("MSE Train"))
  ax1.plot(epochs,sMSE_Val,color="purple",label=("MSE Test"))
  ax1.set_title('MSE')
  ax1.legend()
  ax1.grid()
  

  #Beta 0 and Beta 1
  fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(15, 4))
  ax1.plot(epochs, sBetas0,color="gray")
  ax1.set_title('Beta 0')
  ax1.grid()
  ax2.plot(epochs, sBetas1,color="gray")
  ax2.set_title('Beta 1')
  ax2.grid()

  
  plt.show()

# %%
displayHistory(10,epochs,history)

# %%
#Display 3d : Create an grid for each b0,b1 compute an MSE.
#b0 and b1 are in a range
#-> This part can take a long time

nbPoints = 500;
step = len(history[1])/nbPoints

B0 = []
B1 = []
Epochs = []
MSE = []
for i in range (0,len(history[1])):
  if(i%step ==0):
      Epochs.append(i)
      B0.append(history[2][i])
      B1.append(history[3][i])
      MSE.append(history[1][i])


#2: Create 3D Grid with all possibles values of MSE (brute force)
betas0Values = np.linspace(start=-90, stop=0, num=nbPoints)
betas1Values = np.linspace(start=0, stop=20, num=nbPoints)
graphBeta1, graphBeta0 = np.meshgrid(betas1Values, betas0Values)
graphMSE = np.zeros((nbPoints,nbPoints))
for i in range(nbPoints):
  for j in range (nbPoints):
    beta_1 = graphBeta1[i][j]
    beta_0 = graphBeta0[i][j]
    predictions = []
    for x in X:
      pred = x[0]*beta_1+beta_0
      predictions.append(pred)
    graphMSE[i][j] = mean_squared_error(Y,predictions)

# %%
fig = plt.figure(figsize=[15,12])
ax = plt.axes(projection='3d')

ax.set_xlabel('beta_1', fontsize=20)
ax.set_ylabel('beta_0', fontsize=20)
ax.set_zlabel('mse', fontsize=20)
  
ax.plot_wireframe(graphBeta1, graphBeta0, graphMSE,rstride=10, cstride=10,color="gray",linewidth=0.87)
ax.scatter3D(history[3], history[2], history[0], 'ro', color="red", s=20) 
ax.scatter3D(history[3][-1], history[2][-1], history[0][-1], 'X', color="green", s=200) 
angleElevation=20

ax.view_init(angleElevation, 110)
plt.show()
